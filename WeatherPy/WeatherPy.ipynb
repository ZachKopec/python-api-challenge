# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from datetime import datetime
from scipy import stats


# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

cur_date = datetime.today().strftime ('%m/%d/%Y')

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %%
for value in cities:
    print(f"Processing Record {cities.index(value)} of Set 1 | {value}.")
# Out:
# Processing Record 0 of Set 1 | arlit.
# Processing Record 1 of Set 1 | kilindoni.
# Processing Record 2 of Set 1 | faanui.
# Processing Record 3 of Set 1 | chagda.
# Processing Record 4 of Set 1 | busselton.
# Processing Record 5 of Set 1 | punta arenas.
# Processing Record 6 of Set 1 | albany.
# Processing Record 7 of Set 1 | rangia.
# Processing Record 8 of Set 1 | olocuilta.
# Processing Record 9 of Set 1 | baruun-urt.
# Processing Record 10 of Set 1 | tuktoyaktuk.
# Processing Record 11 of Set 1 | butaritari.
# Processing Record 12 of Set 1 | atambua.
# Processing Record 13 of Set 1 | santiago.
# Processing Record 14 of Set 1 | sentyabrskiy.
# Processing Record 15 of Set 1 | along.
# Processing Record 16 of Set 1 | vaini.
# Processing Record 17 of Set 1 | oliveira dos brejinhos.
# Processing Record 18 of Set 1 | rikitea.
# Processing Record 19 of Set 1 | avarua.
# Processing Record 20 of Set 1 | jamestown.
# Processing Record 21 of Set 1 | staunton.
# Processing Record 22 of Set 1 | east london.
# Processing Record 23 of Set 1 | hilo.
# Processing Record 24 of Set 1 | narsaq.
# Processing Record 25 of Set 1 | ushuaia.
# Processing Record 26 of Set 1 | illoqqortoormiut.
# Processing Record 27 of Set 1 | bluff.
# Processing Record 28 of Set 1 | longyearbyen.
# Processing Record 29 of Set 1 | katsuura.
# Processing Record 30 of Set 1 | guaraniacu.
# Processing Record 31 of Set 1 | nizhneyansk.
# Processing Record 32 of Set 1 | port alfred.
# Processing Record 33 of Set 1 | hithadhoo.
# Processing Record 34 of Set 1 | kupang.
# Processing Record 35 of Set 1 | pinawa.
# Processing Record 36 of Set 1 | vila velha.
# Processing Record 37 of Set 1 | chicama.
# Processing Record 38 of Set 1 | smoky lake.
# Processing Record 39 of Set 1 | dudinka.
# Processing Record 40 of Set 1 | pontal do parana.
# Processing Record 41 of Set 1 | dalaba.
# Processing Record 42 of Set 1 | taolanaro.
# Processing Record 43 of Set 1 | jalu.
# Processing Record 44 of Set 1 | bagdarin.
# Processing Record 45 of Set 1 | mataura.
# Processing Record 46 of Set 1 | jitauna.
# Processing Record 47 of Set 1 | severo-kurilsk.
# Processing Record 48 of Set 1 | pahrump.
# Processing Record 49 of Set 1 | snasa.
# Processing Record 50 of Set 1 | husavik.
# Processing Record 51 of Set 1 | belushya guba.
# Processing Record 52 of Set 1 | lompoc.
# Processing Record 53 of Set 1 | mitchell.
# Processing Record 54 of Set 1 | arraial do cabo.
# Processing Record 55 of Set 1 | puerto ayora.
# Processing Record 56 of Set 1 | cherskiy.
# Processing Record 57 of Set 1 | kapaa.
# Processing Record 58 of Set 1 | panaba.
# Processing Record 59 of Set 1 | victoria.
# Processing Record 60 of Set 1 | hovd.
# Processing Record 61 of Set 1 | port elizabeth.
# Processing Record 62 of Set 1 | mosquera.
# Processing Record 63 of Set 1 | vaitupu.
# Processing Record 64 of Set 1 | qaanaaq.
# Processing Record 65 of Set 1 | esmeraldas.
# Processing Record 66 of Set 1 | olinda.
# Processing Record 67 of Set 1 | sitka.
# Processing Record 68 of Set 1 | bilibino.
# Processing Record 69 of Set 1 | lagoa.
# Processing Record 70 of Set 1 | cidreira.
# Processing Record 71 of Set 1 | nioki.
# Processing Record 72 of Set 1 | lorengau.
# Processing Record 73 of Set 1 | victor harbor.
# Processing Record 74 of Set 1 | dongying.
# Processing Record 75 of Set 1 | vanimo.
# Processing Record 76 of Set 1 | touros.
# Processing Record 77 of Set 1 | atuona.
# Processing Record 78 of Set 1 | gejiu.
# Processing Record 79 of Set 1 | yenagoa.
# Processing Record 80 of Set 1 | bronzani majdan.
# Processing Record 81 of Set 1 | hargeysa.
# Processing Record 82 of Set 1 | te anau.
# Processing Record 83 of Set 1 | namatanai.
# Processing Record 84 of Set 1 | thompson.
# Processing Record 85 of Set 1 | vallentuna.
# Processing Record 86 of Set 1 | sao filipe.
# Processing Record 87 of Set 1 | hobart.
# Processing Record 88 of Set 1 | asfi.
# Processing Record 89 of Set 1 | balabac.
# Processing Record 90 of Set 1 | kaeo.
# Processing Record 91 of Set 1 | lebu.
# Processing Record 92 of Set 1 | geraldton.
# Processing Record 93 of Set 1 | havelock.
# Processing Record 94 of Set 1 | dikson.
# Processing Record 95 of Set 1 | lasa.
# Processing Record 96 of Set 1 | egvekinot.
# Processing Record 97 of Set 1 | upernavik.
# Processing Record 98 of Set 1 | cape town.
# Processing Record 99 of Set 1 | sal rei.
# Processing Record 100 of Set 1 | bathsheba.
# Processing Record 101 of Set 1 | new norfolk.
# Processing Record 102 of Set 1 | bredasdorp.
# Processing Record 103 of Set 1 | mali.
# Processing Record 104 of Set 1 | astipalaia.
# Processing Record 105 of Set 1 | yellowknife.
# Processing Record 106 of Set 1 | abu kamal.
# Processing Record 107 of Set 1 | rolla.
# Processing Record 108 of Set 1 | ostrovnoy.
# Processing Record 109 of Set 1 | mareeba.
# Processing Record 110 of Set 1 | gravdal.
# Processing Record 111 of Set 1 | makakilo city.
# Processing Record 112 of Set 1 | attawapiskat.
# Processing Record 113 of Set 1 | los llanos de aridane.
# Processing Record 114 of Set 1 | rocha.
# Processing Record 115 of Set 1 | nanzhou.
# Processing Record 116 of Set 1 | sisimiut.
# Processing Record 117 of Set 1 | denpasar.
# Processing Record 118 of Set 1 | gambela.
# Processing Record 119 of Set 1 | bethel.
# Processing Record 120 of Set 1 | saint-philippe.
# Processing Record 121 of Set 1 | balclutha.
# Processing Record 122 of Set 1 | umm lajj.
# Processing Record 123 of Set 1 | koulamoutou.
# Processing Record 124 of Set 1 | posse.
# Processing Record 125 of Set 1 | esperance.
# Processing Record 126 of Set 1 | barentsburg.
# Processing Record 127 of Set 1 | rabo de peixe.
# Processing Record 128 of Set 1 | tasiilaq.
# Processing Record 129 of Set 1 | arauca.
# Processing Record 130 of Set 1 | cururupu.
# Processing Record 131 of Set 1 | palabuhanratu.
# Processing Record 132 of Set 1 | ingham.
# Processing Record 133 of Set 1 | hasaki.
# Processing Record 134 of Set 1 | barroquinha.
# Processing Record 135 of Set 1 | pevek.
# Processing Record 136 of Set 1 | alyangula.
# Processing Record 137 of Set 1 | utete.
# Processing Record 138 of Set 1 | juifang.
# Processing Record 139 of Set 1 | kodiak.
# Processing Record 140 of Set 1 | gorgan.
# Processing Record 141 of Set 1 | bobonong.
# Processing Record 142 of Set 1 | hamilton.
# Processing Record 143 of Set 1 | dvinskoy.
# Processing Record 144 of Set 1 | navahrudak.
# Processing Record 145 of Set 1 | hay river.
# Processing Record 146 of Set 1 | ponta do sol.
# Processing Record 147 of Set 1 | airai.
# Processing Record 148 of Set 1 | buin.
# Processing Record 149 of Set 1 | fortuna.
# Processing Record 150 of Set 1 | castro.
# Processing Record 151 of Set 1 | abu dhabi.
# Processing Record 152 of Set 1 | ulety.
# Processing Record 153 of Set 1 | banda aceh.
# Processing Record 154 of Set 1 | qaqortoq.
# Processing Record 155 of Set 1 | barbar.
# Processing Record 156 of Set 1 | neuquen.
# Processing Record 157 of Set 1 | constitucion.
# Processing Record 158 of Set 1 | pankrushikha.
# Processing Record 159 of Set 1 | charters towers.
# Processing Record 160 of Set 1 | leonidovo.
# Processing Record 161 of Set 1 | shimoda.
# Processing Record 162 of Set 1 | hermanus.
# Processing Record 163 of Set 1 | vagur.
# Processing Record 164 of Set 1 | la ronge.
# Processing Record 165 of Set 1 | staffanstorp.
# Processing Record 166 of Set 1 | chamonix-mont-blanc.
# Processing Record 167 of Set 1 | inderborskiy.
# Processing Record 168 of Set 1 | amderma.
# Processing Record 169 of Set 1 | suao.
# Processing Record 170 of Set 1 | hobyo.
# Processing Record 171 of Set 1 | miri.
# Processing Record 172 of Set 1 | cozumel.
# Processing Record 173 of Set 1 | samarai.
# Processing Record 174 of Set 1 | isangel.
# Processing Record 175 of Set 1 | high rock.
# Processing Record 176 of Set 1 | cody.
# Processing Record 177 of Set 1 | nanortalik.
# Processing Record 178 of Set 1 | nikolskoye.
# Processing Record 179 of Set 1 | jambi.
# Processing Record 180 of Set 1 | calama.
# Processing Record 181 of Set 1 | kargil.
# Processing Record 182 of Set 1 | ribeira grande.
# Processing Record 183 of Set 1 | georgetown.
# Processing Record 184 of Set 1 | iqaluit.
# Processing Record 185 of Set 1 | ahipara.
# Processing Record 186 of Set 1 | saskylakh.
# Processing Record 187 of Set 1 | port hardy.
# Processing Record 188 of Set 1 | brattvag.
# Processing Record 189 of Set 1 | tateyama.
# Processing Record 190 of Set 1 | leningradskiy.
# Processing Record 191 of Set 1 | kamenskoye.
# Processing Record 192 of Set 1 | perehonivka.
# Processing Record 193 of Set 1 | tenamaxtlan.
# Processing Record 194 of Set 1 | half moon bay.
# Processing Record 195 of Set 1 | gizo.
# Processing Record 196 of Set 1 | kenora.
# Processing Record 197 of Set 1 | deputatskiy.
# Processing Record 198 of Set 1 | korla.
# Processing Record 199 of Set 1 | coahuayana.
# Processing Record 200 of Set 1 | kirakira.
# Processing Record 201 of Set 1 | kaitangata.
# Processing Record 202 of Set 1 | tezu.
# Processing Record 203 of Set 1 | taltal.
# Processing Record 204 of Set 1 | baoding.
# Processing Record 205 of Set 1 | worthington.
# Processing Record 206 of Set 1 | palmaner.
# Processing Record 207 of Set 1 | benghazi.
# Processing Record 208 of Set 1 | maun.
# Processing Record 209 of Set 1 | bambous virieux.
# Processing Record 210 of Set 1 | umm kaddadah.
# Processing Record 211 of Set 1 | sofiyivka.
# Processing Record 212 of Set 1 | oktyabrskoye.
# Processing Record 213 of Set 1 | chuy.
# Processing Record 214 of Set 1 | port macquarie.
# Processing Record 215 of Set 1 | mahebourg.
# Processing Record 216 of Set 1 | sai buri.
# Processing Record 217 of Set 1 | belmonte.
# Processing Record 218 of Set 1 | puerto maldonado.
# Processing Record 219 of Set 1 | araioses.
# Processing Record 220 of Set 1 | champerico.
# Processing Record 221 of Set 1 | port lincoln.
# Processing Record 222 of Set 1 | necochea.
# Processing Record 223 of Set 1 | mahajanga.
# Processing Record 224 of Set 1 | khatanga.
# Processing Record 225 of Set 1 | port hedland.
# Processing Record 226 of Set 1 | kahului.
# Processing Record 227 of Set 1 | eureka.
# Processing Record 228 of Set 1 | namibe.
# Processing Record 229 of Set 1 | czluchow.
# Processing Record 230 of Set 1 | ust-nera.
# Processing Record 231 of Set 1 | keti bandar.
# Processing Record 232 of Set 1 | harper.
# Processing Record 233 of Set 1 | leh.
# Processing Record 234 of Set 1 | tuatapere.
# Processing Record 235 of Set 1 | mar del plata.
# Processing Record 236 of Set 1 | bitung.
# Processing Record 237 of Set 1 | nuevo progreso.
# Processing Record 238 of Set 1 | khani.
# Processing Record 239 of Set 1 | alofi.
# Processing Record 240 of Set 1 | barrow.
# Processing Record 241 of Set 1 | provideniya.
# Processing Record 242 of Set 1 | bethal.
# Processing Record 243 of Set 1 | igrim.
# Processing Record 244 of Set 1 | changqing.
# Processing Record 245 of Set 1 | marcona.
# Processing Record 246 of Set 1 | kloulklubed.
# Processing Record 247 of Set 1 | bengkulu.
# Processing Record 248 of Set 1 | pecos.
# Processing Record 249 of Set 1 | chokurdakh.
# Processing Record 250 of Set 1 | grindavik.
# Processing Record 251 of Set 1 | merano.
# Processing Record 252 of Set 1 | huilong.
# Processing Record 253 of Set 1 | solovetskiy.
# Processing Record 254 of Set 1 | tiksi.
# Processing Record 255 of Set 1 | northam.
# Processing Record 256 of Set 1 | liverpool.
# Processing Record 257 of Set 1 | sagua la grande.
# Processing Record 258 of Set 1 | vardo.
# Processing Record 259 of Set 1 | tautira.
# Processing Record 260 of Set 1 | luderitz.
# Processing Record 261 of Set 1 | mys shmidta.
# Processing Record 262 of Set 1 | sur.
# Processing Record 263 of Set 1 | bolungarvik.
# Processing Record 264 of Set 1 | oxelosund.
# Processing Record 265 of Set 1 | norfolk.
# Processing Record 266 of Set 1 | cabo san lucas.
# Processing Record 267 of Set 1 | san cristobal.
# Processing Record 268 of Set 1 | adrar.
# Processing Record 269 of Set 1 | akyab.
# Processing Record 270 of Set 1 | quelimane.
# Processing Record 271 of Set 1 | axim.
# Processing Record 272 of Set 1 | kidal.
# Processing Record 273 of Set 1 | tomatlan.
# Processing Record 274 of Set 1 | rio grande.
# Processing Record 275 of Set 1 | polson.
# Processing Record 276 of Set 1 | onega.
# Processing Record 277 of Set 1 | jasper.
# Processing Record 278 of Set 1 | tungor.
# Processing Record 279 of Set 1 | mentok.
# Processing Record 280 of Set 1 | kamenka.
# Processing Record 281 of Set 1 | catamarca.
# Processing Record 282 of Set 1 | grand centre.
# Processing Record 283 of Set 1 | tunghsiao.
# Processing Record 284 of Set 1 | gat.
# Processing Record 285 of Set 1 | mount isa.
# Processing Record 286 of Set 1 | kropotkin.
# Processing Record 287 of Set 1 | port pirie.
# Processing Record 288 of Set 1 | klaksvik.
# Processing Record 289 of Set 1 | narrabri.
# Processing Record 290 of Set 1 | shwebo.
# Processing Record 291 of Set 1 | cherdyn.
# Processing Record 292 of Set 1 | kokkola.
# Processing Record 293 of Set 1 | safranbolu.
# Processing Record 294 of Set 1 | broome.
# Processing Record 295 of Set 1 | singaparna.
# Processing Record 296 of Set 1 | shiraz.
# Processing Record 297 of Set 1 | hami.
# Processing Record 298 of Set 1 | cleethorpes.
# Processing Record 299 of Set 1 | port-cartier.
# Processing Record 300 of Set 1 | ipinda.
# Processing Record 301 of Set 1 | comodoro rivadavia.
# Processing Record 302 of Set 1 | honningsvag.
# Processing Record 303 of Set 1 | milazzo.
# Processing Record 304 of Set 1 | paamiut.
# Processing Record 305 of Set 1 | flin flon.
# Processing Record 306 of Set 1 | puerto escondido.
# Processing Record 307 of Set 1 | encruzilhada do sul.
# Processing Record 308 of Set 1 | mao.
# Processing Record 309 of Set 1 | sorland.
# Processing Record 310 of Set 1 | ruatoria.
# Processing Record 311 of Set 1 | batsfjord.
# Processing Record 312 of Set 1 | khandyga.
# Processing Record 313 of Set 1 | mocuba.
# Processing Record 314 of Set 1 | ranau.
# Processing Record 315 of Set 1 | panjakent.
# Processing Record 316 of Set 1 | maroantsetra.
# Processing Record 317 of Set 1 | timmins.
# Processing Record 318 of Set 1 | roma.
# Processing Record 319 of Set 1 | andros.
# Processing Record 320 of Set 1 | pangody.
# Processing Record 321 of Set 1 | tuy hoa.
# Processing Record 322 of Set 1 | aklavik.
# Processing Record 323 of Set 1 | pathein.
# Processing Record 324 of Set 1 | biak.
# Processing Record 325 of Set 1 | kiama.
# Processing Record 326 of Set 1 | kirriemuir.
# Processing Record 327 of Set 1 | marfino.
# Processing Record 328 of Set 1 | roald.
# Processing Record 329 of Set 1 | grand gaube.
# Processing Record 330 of Set 1 | laguna.
# Processing Record 331 of Set 1 | chaupal.
# Processing Record 332 of Set 1 | saint-georges.
# Processing Record 333 of Set 1 | lewistown.
# Processing Record 334 of Set 1 | bokspits.
# Processing Record 335 of Set 1 | tsihombe.
# Processing Record 336 of Set 1 | codrington.
# Processing Record 337 of Set 1 | boueni.
# Processing Record 338 of Set 1 | maralal.
# Processing Record 339 of Set 1 | qibili.
# Processing Record 340 of Set 1 | hualmay.
# Processing Record 341 of Set 1 | beloha.
# Processing Record 342 of Set 1 | saint george.
# Processing Record 343 of Set 1 | sarande.
# Processing Record 344 of Set 1 | sangar.
# Processing Record 345 of Set 1 | hihifo.
# Processing Record 346 of Set 1 | belle fourche.
# Processing Record 347 of Set 1 | dingle.
# Processing Record 348 of Set 1 | amapa.
# Processing Record 349 of Set 1 | thaton.
# Processing Record 350 of Set 1 | nueva italia.
# Processing Record 351 of Set 1 | key biscayne.
# Processing Record 352 of Set 1 | nedjo.
# Processing Record 353 of Set 1 | makinsk.
# Processing Record 354 of Set 1 | ovalle.
# Processing Record 355 of Set 1 | camacha.
# Processing Record 356 of Set 1 | japura.
# Processing Record 357 of Set 1 | amahai.
# Processing Record 358 of Set 1 | ayan.
# Processing Record 359 of Set 1 | strezhevoy.
# Processing Record 360 of Set 1 | lardos.
# Processing Record 361 of Set 1 | orlik.
# Processing Record 362 of Set 1 | bulawayo.
# Processing Record 363 of Set 1 | alta floresta.
# Processing Record 364 of Set 1 | the pas.
# Processing Record 365 of Set 1 | vostok.
# Processing Record 366 of Set 1 | cap-aux-meules.
# Processing Record 367 of Set 1 | kharitonovo.
# Processing Record 368 of Set 1 | yefira.
# Processing Record 369 of Set 1 | springfield.
# Processing Record 370 of Set 1 | takaka.
# Processing Record 371 of Set 1 | candawaga.
# Processing Record 372 of Set 1 | norman wells.
# Processing Record 373 of Set 1 | carnarvon.
# Processing Record 374 of Set 1 | sept-iles.
# Processing Record 375 of Set 1 | tiarei.
# Processing Record 376 of Set 1 | ixtapa.
# Processing Record 377 of Set 1 | lolua.
# Processing Record 378 of Set 1 | sioux lookout.
# Processing Record 379 of Set 1 | severnyy.
# Processing Record 380 of Set 1 | dali.
# Processing Record 381 of Set 1 | launceston.
# Processing Record 382 of Set 1 | tigil.
# Processing Record 383 of Set 1 | talas.
# Processing Record 384 of Set 1 | shumskiy.
# Processing Record 385 of Set 1 | clinton.
# Processing Record 386 of Set 1 | metro.
# Processing Record 387 of Set 1 | sinnamary.
# Processing Record 388 of Set 1 | huntington beach.
# Processing Record 389 of Set 1 | poim.
# Processing Record 390 of Set 1 | vestmannaeyjar.
# Processing Record 391 of Set 1 | trincomalee.
# Processing Record 392 of Set 1 | miandrivazo.
# Processing Record 393 of Set 1 | zhigansk.
# Processing Record 394 of Set 1 | sibolga.
# Processing Record 395 of Set 1 | kenai.
# Processing Record 396 of Set 1 | robertsport.
# Processing Record 397 of Set 1 | salta.
# Processing Record 398 of Set 1 | kortkeros.
# Processing Record 399 of Set 1 | andros town.
# Processing Record 400 of Set 1 | majene.
# Processing Record 401 of Set 1 | tabas.
# Processing Record 402 of Set 1 | pemangkat.
# Processing Record 403 of Set 1 | tarko-sale.
# Processing Record 404 of Set 1 | bella union.
# Processing Record 405 of Set 1 | itamaraju.
# Processing Record 406 of Set 1 | muborak.
# Processing Record 407 of Set 1 | menongue.
# Processing Record 408 of Set 1 | clyde river.
# Processing Record 409 of Set 1 | vila do maio.
# Processing Record 410 of Set 1 | novi pazar.
# Processing Record 411 of Set 1 | khash.
# Processing Record 412 of Set 1 | samusu.
# Processing Record 413 of Set 1 | mangrol.
# Processing Record 414 of Set 1 | awbari.
# Processing Record 415 of Set 1 | antofagasta.
# Processing Record 416 of Set 1 | shingu.
# Processing Record 417 of Set 1 | bloemfontein.
# Processing Record 418 of Set 1 | koshurnikovo.
# Processing Record 419 of Set 1 | krasnyy chikoy.
# Processing Record 420 of Set 1 | kerchevskiy.
# Processing Record 421 of Set 1 | neiafu.
# Processing Record 422 of Set 1 | presidencia roque saenz pena.
# Processing Record 423 of Set 1 | tatawin.
# Processing Record 424 of Set 1 | talnakh.
# Processing Record 425 of Set 1 | salama.
# Processing Record 426 of Set 1 | ellensburg.
# Processing Record 427 of Set 1 | ust-omchug.
# Processing Record 428 of Set 1 | manaskent.
# Processing Record 429 of Set 1 | alugan.
# Processing Record 430 of Set 1 | mizdah.
# Processing Record 431 of Set 1 | usva.
# Processing Record 432 of Set 1 | ilulissat.
# Processing Record 433 of Set 1 | elko.
# Processing Record 434 of Set 1 | aberdeen.
# Processing Record 435 of Set 1 | ancud.
# Processing Record 436 of Set 1 | sabang.
# Processing Record 437 of Set 1 | idlib.
# Processing Record 438 of Set 1 | saint charles.
# Processing Record 439 of Set 1 | sao jose da coroa grande.
# Processing Record 440 of Set 1 | coihaique.
# Processing Record 441 of Set 1 | ambilobe.
# Processing Record 442 of Set 1 | kuytun.
# Processing Record 443 of Set 1 | tekeli.
# Processing Record 444 of Set 1 | khonuu.
# Processing Record 445 of Set 1 | san carlos de bariloche.
# Processing Record 446 of Set 1 | visby.
# Processing Record 447 of Set 1 | yining.
# Processing Record 448 of Set 1 | jiwani.
# Processing Record 449 of Set 1 | varkaus.
# Processing Record 450 of Set 1 | taoudenni.
# Processing Record 451 of Set 1 | clyde.
# Processing Record 452 of Set 1 | mecca.
# Processing Record 453 of Set 1 | aitape.
# Processing Record 454 of Set 1 | noumea.
# Processing Record 455 of Set 1 | mweka.
# Processing Record 456 of Set 1 | misratah.
# Processing Record 457 of Set 1 | jiuquan.
# Processing Record 458 of Set 1 | zyryanka.
# Processing Record 459 of Set 1 | madimba.
# Processing Record 460 of Set 1 | grand river south east.
# Processing Record 461 of Set 1 | kawambwa.
# Processing Record 462 of Set 1 | batagay.
# Processing Record 463 of Set 1 | saldanha.
# Processing Record 464 of Set 1 | marquette.
# Processing Record 465 of Set 1 | poso.
# Processing Record 466 of Set 1 | bereznik.
# Processing Record 467 of Set 1 | togur.
# Processing Record 468 of Set 1 | pundaguitan.
# Processing Record 469 of Set 1 | chifeng.
# Processing Record 470 of Set 1 | katherine.
# Processing Record 471 of Set 1 | san quintin.
# Processing Record 472 of Set 1 | port blair.
# Processing Record 473 of Set 1 | san lorenzo.
# Processing Record 474 of Set 1 | nuuk.
# Processing Record 475 of Set 1 | seoul.
# Processing Record 476 of Set 1 | krasnovishersk.
# Processing Record 477 of Set 1 | monroe.
# Processing Record 478 of Set 1 | santa cruz.
# Processing Record 479 of Set 1 | jorpeland.
# Processing Record 480 of Set 1 | salalah.
# Processing Record 481 of Set 1 | broken hill.
# Processing Record 482 of Set 1 | kuzino.
# Processing Record 483 of Set 1 | honiara.
# Processing Record 484 of Set 1 | warner robins.
# Processing Record 485 of Set 1 | cheney.
# Processing Record 486 of Set 1 | hurghada.
# Processing Record 487 of Set 1 | rawah.
# Processing Record 488 of Set 1 | mount gambier.
# Processing Record 489 of Set 1 | borovskoy.
# Processing Record 490 of Set 1 | pangnirtung.
# Processing Record 491 of Set 1 | mackay.
# Processing Record 492 of Set 1 | krasnogvardeyskiy.
# Processing Record 493 of Set 1 | thessalon.
# Processing Record 494 of Set 1 | santa clarita.
# Processing Record 495 of Set 1 | barda.
# Processing Record 496 of Set 1 | sao felix do xingu.
# Processing Record 497 of Set 1 | vao.
# Processing Record 498 of Set 1 | eravur.
# Processing Record 499 of Set 1 | watsa.
# Processing Record 500 of Set 1 | torbay.
# Processing Record 501 of Set 1 | namtsy.
# Processing Record 502 of Set 1 | liuli.
# Processing Record 503 of Set 1 | moranbah.
# Processing Record 504 of Set 1 | yingcheng.
# Processing Record 505 of Set 1 | acari.
# Processing Record 506 of Set 1 | puertollano.
# Processing Record 507 of Set 1 | makat.
# Processing Record 508 of Set 1 | sao francisco do sul.
# Processing Record 509 of Set 1 | itarema.
# Processing Record 510 of Set 1 | ende.
# Processing Record 511 of Set 1 | edson.
# Processing Record 512 of Set 1 | chudovo.
# Processing Record 513 of Set 1 | samalaeulu.
# Processing Record 514 of Set 1 | perez.
# Processing Record 515 of Set 1 | lively.
# Processing Record 516 of Set 1 | kon tum.
# Processing Record 517 of Set 1 | ossora.
# Processing Record 518 of Set 1 | takoradi.
# Processing Record 519 of Set 1 | gorom-gorom.
# Processing Record 520 of Set 1 | pachino.
# Processing Record 521 of Set 1 | college.
# Processing Record 522 of Set 1 | inhambane.
# Processing Record 523 of Set 1 | sartell.
# Processing Record 524 of Set 1 | san ramon.
# Processing Record 525 of Set 1 | sinjah.
# Processing Record 526 of Set 1 | kruisfontein.
# Processing Record 527 of Set 1 | ndouci.
# Processing Record 528 of Set 1 | pisco.
# Processing Record 529 of Set 1 | tabulbah.
# Processing Record 530 of Set 1 | toora-khem.
# Processing Record 531 of Set 1 | yulin.
# Processing Record 532 of Set 1 | raudeberg.
# Processing Record 533 of Set 1 | karkaralinsk.
# Processing Record 534 of Set 1 | linchuan.
# Processing Record 535 of Set 1 | pyaozerskiy.
# Processing Record 536 of Set 1 | dzhebariki-khaya.
# Processing Record 537 of Set 1 | quatre cocos.
# Processing Record 538 of Set 1 | osakarovka.
# Processing Record 539 of Set 1 | boa esperanca do sul.
# Processing Record 540 of Set 1 | turbat.
# Processing Record 541 of Set 1 | masunga.
# Processing Record 542 of Set 1 | siuna.
# Processing Record 543 of Set 1 | lakes entrance.
# Processing Record 544 of Set 1 | mirina.
# Processing Record 545 of Set 1 | terrace.
# Processing Record 546 of Set 1 | faya.
# Processing Record 547 of Set 1 | lichinga.
# Processing Record 548 of Set 1 | kamaishi.
# Processing Record 549 of Set 1 | robore.
# Processing Record 550 of Set 1 | tecoanapa.
# Processing Record 551 of Set 1 | palora.
# Processing Record 552 of Set 1 | marsa matruh.
# Processing Record 553 of Set 1 | banjar.
# Processing Record 554 of Set 1 | lavrentiya.
# Processing Record 555 of Set 1 | dunedin.
# Processing Record 556 of Set 1 | oyem.
# Processing Record 557 of Set 1 | bandarbeyla.
# Processing Record 558 of Set 1 | yamaga.
# Processing Record 559 of Set 1 | aasiaat.
# Processing Record 560 of Set 1 | ninghai.
# Processing Record 561 of Set 1 | yambio.
# Processing Record 562 of Set 1 | ravanusa.
# Processing Record 563 of Set 1 | bellevue.
# Processing Record 564 of Set 1 | granada.
# Processing Record 565 of Set 1 | cockburn town.
# Processing Record 566 of Set 1 | keflavik.
# Processing Record 567 of Set 1 | aksarka.
# Processing Record 568 of Set 1 | davila.
# Processing Record 569 of Set 1 | sicamous.
# Processing Record 570 of Set 1 | kavaratti.
# Processing Record 571 of Set 1 | jurm.
# Processing Record 572 of Set 1 | coquimbo.
# Processing Record 573 of Set 1 | basco.
# Processing Record 574 of Set 1 | cagayan de tawi-tawi.
# Processing Record 575 of Set 1 | alotau.
# Processing Record 576 of Set 1 | labuhan.
# Processing Record 577 of Set 1 | peniche.
# Processing Record 578 of Set 1 | skibby.
# Processing Record 579 of Set 1 | batagay-alyta.
# Processing Record 580 of Set 1 | ilanskiy.
# Processing Record 581 of Set 1 | ko samui.
# Processing Record 582 of Set 1 | greytown.
# Processing Record 583 of Set 1 | fairbanks.
# Processing Record 584 of Set 1 | caravelas.
# Processing Record 585 of Set 1 | anito.
# Processing Record 586 of Set 1 | dwarka.
# Processing Record 587 of Set 1 | bosobolo.
# Processing Record 588 of Set 1 | bokoro.
# Processing Record 589 of Set 1 | rosarito.
# Processing Record 590 of Set 1 | bulungu.
# Processing Record 591 of Set 1 | hambantota.
# Processing Record 592 of Set 1 | andevoranto.
# Processing Record 593 of Set 1 | yanam.
# Processing Record 594 of Set 1 | haapiti.
# Processing Record 595 of Set 1 | timra.
# Processing Record 596 of Set 1 | matay.
# Processing Record 597 of Set 1 | mazarron.
# Processing Record 598 of Set 1 | atasu.
# Processing Record 599 of Set 1 | do rud.
# Processing Record 600 of Set 1 | merke.
# Processing Record 601 of Set 1 | bajil.
# Processing Record 602 of Set 1 | louisbourg.
# Processing Record 603 of Set 1 | wahiawa.
# Processing Record 604 of Set 1 | chengde.
# Processing Record 605 of Set 1 | lazarev.

# %%
# set up lists to hold reponse info

lat = []
lng = []
temp = []
humidity = []
cloud = []
wind_speed = []
country = []
date = []

# Loop through the list of cities and perform a request for data on each
for area in cities:
    
    try:
        
        response = requests.get(query_url + area).json()

        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response["sys"]["country"])
        date.append(cur_date)
    
        print(f"{area} {lat} {lng} {temp} {humidity} {wind_speed} {country}")
    
    except KeyError:
    
        print(f"{area}, doesn't have information.")
        lat.append(None)
        lng.append(None)
        temp.append(None)
        humidity.append(None)
        cloud.append(None)
        wind_speed.append(None)
        country.append(None)
        date.append(None)
# Out:
# arlit, doesn't have information.
# kilindoni, doesn't have information.
# faanui, doesn't have information.
# chagda, doesn't have information.
# busselton, doesn't have information.
# punta arenas, doesn't have information.
# albany, doesn't have information.
# rangia, doesn't have information.
# olocuilta, doesn't have information.
# baruun-urt, doesn't have information.
# tuktoyaktuk, doesn't have information.
# butaritari, doesn't have information.
# atambua, doesn't have information.
# santiago, doesn't have information.
# sentyabrskiy, doesn't have information.
# along, doesn't have information.
# vaini, doesn't have information.
# oliveira dos brejinhos, doesn't have information.
# rikitea, doesn't have information.
# avarua, doesn't have information.
# jamestown, doesn't have information.
# staunton, doesn't have information.
# east london, doesn't have information.
# hilo, doesn't have information.
# narsaq, doesn't have information.
# ushuaia, doesn't have information.
# illoqqortoormiut, doesn't have information.
# bluff, doesn't have information.
# longyearbyen, doesn't have information.
# katsuura, doesn't have information.
# guaraniacu, doesn't have information.
# nizhneyansk, doesn't have information.
# port alfred, doesn't have information.
# hithadhoo, doesn't have information.
# kupang, doesn't have information.
# pinawa, doesn't have information.
# vila velha, doesn't have information.
# chicama, doesn't have information.
# smoky lake, doesn't have information.
# dudinka, doesn't have information.
# pontal do parana, doesn't have information.
# dalaba, doesn't have information.
# taolanaro, doesn't have information.
# jalu, doesn't have information.
# bagdarin, doesn't have information.
# mataura, doesn't have information.
# jitauna, doesn't have information.
# severo-kurilsk, doesn't have information.
# pahrump, doesn't have information.
# snasa, doesn't have information.
# husavik, doesn't have information.
# belushya guba, doesn't have information.
# lompoc, doesn't have information.
# mitchell, doesn't have information.
# arraial do cabo, doesn't have information.
# puerto ayora, doesn't have information.
# cherskiy, doesn't have information.
# kapaa, doesn't have information.
# panaba, doesn't have information.
# victoria, doesn't have information.
# hovd, doesn't have information.
# port elizabeth, doesn't have information.
# mosquera, doesn't have information.
# vaitupu, doesn't have information.
# qaanaaq, doesn't have information.
# esmeraldas, doesn't have information.
# olinda, doesn't have information.
# sitka, doesn't have information.
# bilibino, doesn't have information.
# lagoa, doesn't have information.
# cidreira, doesn't have information.
# nioki, doesn't have information.
# lorengau, doesn't have information.
# victor harbor, doesn't have information.
# dongying, doesn't have information.
# vanimo, doesn't have information.
# touros, doesn't have information.
# atuona, doesn't have information.
# gejiu, doesn't have information.
# yenagoa, doesn't have information.
# bronzani majdan, doesn't have information.
# hargeysa, doesn't have information.
# te anau, doesn't have information.
# namatanai, doesn't have information.
# thompson, doesn't have information.
# vallentuna, doesn't have information.
# sao filipe, doesn't have information.
# hobart, doesn't have information.
# asfi, doesn't have information.
# balabac, doesn't have information.
# kaeo, doesn't have information.
# lebu, doesn't have information.
# geraldton, doesn't have information.
# havelock, doesn't have information.
# dikson, doesn't have information.
# lasa, doesn't have information.
# egvekinot, doesn't have information.
# upernavik, doesn't have information.
# cape town, doesn't have information.
# sal rei, doesn't have information.
# bathsheba, doesn't have information.
# new norfolk, doesn't have information.
# bredasdorp, doesn't have information.
# mali, doesn't have information.
# astipalaia, doesn't have information.
# yellowknife, doesn't have information.
# abu kamal, doesn't have information.
# rolla, doesn't have information.
# ostrovnoy, doesn't have information.
# mareeba, doesn't have information.
# gravdal, doesn't have information.
# makakilo city, doesn't have information.
# attawapiskat, doesn't have information.
# los llanos de aridane, doesn't have information.
# rocha, doesn't have information.
# nanzhou, doesn't have information.
# sisimiut, doesn't have information.
# denpasar, doesn't have information.
# gambela, doesn't have information.
# bethel, doesn't have information.
# saint-philippe, doesn't have information.
# balclutha, doesn't have information.
# umm lajj, doesn't have information.
# koulamoutou, doesn't have information.
# posse, doesn't have information.
# esperance, doesn't have information.
# barentsburg, doesn't have information.
# rabo de peixe, doesn't have information.
# tasiilaq, doesn't have information.
# arauca, doesn't have information.
# cururupu, doesn't have information.
# palabuhanratu, doesn't have information.
# ingham, doesn't have information.
# hasaki, doesn't have information.
# barroquinha, doesn't have information.
# pevek, doesn't have information.
# alyangula, doesn't have information.
# utete, doesn't have information.
# juifang, doesn't have information.
# kodiak, doesn't have information.
# gorgan, doesn't have information.
# bobonong, doesn't have information.
# hamilton, doesn't have information.
# dvinskoy, doesn't have information.
# navahrudak, doesn't have information.
# hay river, doesn't have information.
# ponta do sol, doesn't have information.
# airai, doesn't have information.
# buin, doesn't have information.
# fortuna, doesn't have information.
# castro, doesn't have information.
# abu dhabi, doesn't have information.
# ulety, doesn't have information.
# banda aceh, doesn't have information.
# qaqortoq, doesn't have information.
# barbar, doesn't have information.
# neuquen, doesn't have information.
# constitucion, doesn't have information.
# pankrushikha, doesn't have information.
# charters towers, doesn't have information.
# leonidovo, doesn't have information.
# shimoda, doesn't have information.
# hermanus, doesn't have information.
# vagur, doesn't have information.
# la ronge, doesn't have information.
# staffanstorp, doesn't have information.
# chamonix-mont-blanc, doesn't have information.
# inderborskiy, doesn't have information.
# amderma, doesn't have information.
# suao, doesn't have information.
# hobyo, doesn't have information.
# miri, doesn't have information.
# cozumel, doesn't have information.
# samarai, doesn't have information.
# isangel, doesn't have information.
# high rock, doesn't have information.
# cody, doesn't have information.
# nanortalik, doesn't have information.
# nikolskoye, doesn't have information.
# jambi, doesn't have information.
# calama, doesn't have information.
# kargil, doesn't have information.
# ribeira grande, doesn't have information.
# georgetown, doesn't have information.
# iqaluit, doesn't have information.
# ahipara, doesn't have information.
# saskylakh, doesn't have information.
# port hardy, doesn't have information.
# brattvag, doesn't have information.
# tateyama, doesn't have information.
# leningradskiy, doesn't have information.
# kamenskoye, doesn't have information.
# perehonivka, doesn't have information.
# tenamaxtlan, doesn't have information.
# half moon bay, doesn't have information.
# gizo, doesn't have information.
# kenora, doesn't have information.
# deputatskiy, doesn't have information.
# korla, doesn't have information.
# coahuayana, doesn't have information.
# kirakira, doesn't have information.
# kaitangata, doesn't have information.
# tezu, doesn't have information.
# taltal, doesn't have information.
# baoding, doesn't have information.
# worthington, doesn't have information.
# palmaner, doesn't have information.
# benghazi, doesn't have information.
# maun, doesn't have information.
# bambous virieux, doesn't have information.
# umm kaddadah, doesn't have information.
# sofiyivka, doesn't have information.
# oktyabrskoye, doesn't have information.
# chuy, doesn't have information.
# port macquarie, doesn't have information.
# mahebourg, doesn't have information.
# sai buri, doesn't have information.
# belmonte, doesn't have information.
# puerto maldonado, doesn't have information.
# araioses, doesn't have information.
# champerico, doesn't have information.
# port lincoln, doesn't have information.
# necochea, doesn't have information.
# mahajanga, doesn't have information.
# khatanga, doesn't have information.
# port hedland, doesn't have information.
# kahului, doesn't have information.
# eureka, doesn't have information.
# namibe, doesn't have information.
# czluchow, doesn't have information.
# ust-nera, doesn't have information.
# keti bandar, doesn't have information.
# harper, doesn't have information.
# leh, doesn't have information.
# tuatapere, doesn't have information.
# mar del plata, doesn't have information.
# bitung, doesn't have information.
# nuevo progreso, doesn't have information.
# khani, doesn't have information.
# alofi, doesn't have information.
# barrow, doesn't have information.
# provideniya, doesn't have information.
# bethal, doesn't have information.
# igrim, doesn't have information.
# changqing, doesn't have information.
# marcona, doesn't have information.
# kloulklubed, doesn't have information.
# bengkulu, doesn't have information.
# pecos, doesn't have information.
# chokurdakh, doesn't have information.
# grindavik, doesn't have information.
# merano, doesn't have information.
# huilong, doesn't have information.
# solovetskiy, doesn't have information.
# tiksi, doesn't have information.
# northam, doesn't have information.
# liverpool, doesn't have information.
# sagua la grande, doesn't have information.
# vardo, doesn't have information.
# tautira, doesn't have information.
# luderitz, doesn't have information.
# mys shmidta, doesn't have information.
# sur, doesn't have information.
# bolungarvik, doesn't have information.
# oxelosund, doesn't have information.
# norfolk, doesn't have information.
# cabo san lucas, doesn't have information.
# san cristobal, doesn't have information.
# adrar, doesn't have information.
# akyab, doesn't have information.
# quelimane, doesn't have information.
# axim, doesn't have information.
# kidal, doesn't have information.
# tomatlan, doesn't have information.
# rio grande, doesn't have information.
# polson, doesn't have information.
# onega, doesn't have information.
# jasper, doesn't have information.
# tungor, doesn't have information.
# mentok, doesn't have information.
# kamenka, doesn't have information.
# catamarca, doesn't have information.
# grand centre, doesn't have information.
# tunghsiao, doesn't have information.
# gat, doesn't have information.
# mount isa, doesn't have information.
# kropotkin, doesn't have information.
# port pirie, doesn't have information.
# klaksvik, doesn't have information.
# narrabri, doesn't have information.
# shwebo, doesn't have information.
# cherdyn, doesn't have information.
# kokkola, doesn't have information.
# safranbolu, doesn't have information.
# broome, doesn't have information.
# singaparna, doesn't have information.
# shiraz, doesn't have information.
# hami, doesn't have information.
# cleethorpes, doesn't have information.
# port-cartier, doesn't have information.
# ipinda, doesn't have information.
# comodoro rivadavia, doesn't have information.
# honningsvag, doesn't have information.
# milazzo, doesn't have information.
# paamiut, doesn't have information.
# flin flon, doesn't have information.
# puerto escondido, doesn't have information.
# encruzilhada do sul, doesn't have information.
# mao, doesn't have information.
# sorland, doesn't have information.
# ruatoria, doesn't have information.
# batsfjord, doesn't have information.
# khandyga, doesn't have information.
# mocuba, doesn't have information.
# ranau, doesn't have information.
# panjakent, doesn't have information.
# maroantsetra, doesn't have information.
# timmins, doesn't have information.
# roma, doesn't have information.
# andros, doesn't have information.

# %%
city_weather_dict = {
    "City": cities,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": temp,
    "Humidity": humidity,
    "Cloudiness": cloud,
    "Wind Speed": wind_speed,
    "County": country,
    "Date": date
}

# create a data frame from cities, lat, and temp

weather_data = pd.DataFrame(city_weather_dict)
weather_data.head()

# %%
weather_data.to_csv(output_data_file)

# %%
plt.scatter(weather_data['Lat'], weather_data["Max Temp"], color = "blue")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title("City Latitute vs. Max Temperature " + cur_date)
plt.grid()
plt.savefig("Lat vs. Max Temp.png")
plt.show()

#The plot below displays the max temperature of a city based on its vertical location on Earth.
#The higher and lower from 0 the latitude is, the lower the max temperature should be.

# %%
plt.scatter(weather_data['Lat'], weather_data["Humidity"], color = "blue")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitute vs. Humidity " + cur_date)
plt.grid()
plt.savefig("Lat vs. Humidity.png")
plt.show()

#The plot below displays the humidity of a city based on its vertical location on Earth.
#The higher and lower from 0 the latitude is, the lower the humidity should be.

# %%
plt.scatter(weather_data['Lat'], weather_data["Cloudiness"], color = "blue")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitute vs. Cloudiness " + cur_date)
plt.grid()
plt.savefig("Lat vs. Cloudiness.png")
plt.show()

#The plot below displays the cloudiness of a city based on its vertical location on Earth.

# %%
plt.scatter(weather_data['Lat'], weather_data["Wind Speed"], color = "blue")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitute vs. Wind Speed " + cur_date)
plt.grid()
plt.savefig("Lat vs. Wind Speed.png")
plt.show()

#The plot below displays the wind speed of a city based on its vertical location on Earth.

# %%
x_val = weather_data['Lat'].dropna()
y_val = weather_data['Max Temp'].dropna()
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(weather_data['Lat'], weather_data['Max Temp'])

regress_value = weather_data['Max Temp'] * slope + intercept

line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] >= 0]
y_val = weather_data['Max Temp'].loc[weather_data['Lat'] >= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] >= 0], weather_data['Max Temp'].loc[weather_data['Lat'] >= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(46,60), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("City Latitute vs. Max Temp")
plt.savefig("Northern Hemisphere Temp Regression")
plt.show()

#The below plot is showing a trend of decreasing temperatures, the further away from the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] <= 0]
y_val = weather_data['Max Temp'].loc[weather_data['Lat'] <= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] <= 0], weather_data['Max Temp'].loc[weather_data['Lat'] <= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(-50,80), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("City Latitute vs. Max Temp " + cur_date)
plt.savefig("Southern Hemisphere Temp Regression")
plt.show()

#The below plot is showing a trend of increasing temperatures, the closer to the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] >= 0]
y_val = weather_data['Humidity'].loc[weather_data['Lat'] >= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] >= 0], weather_data['Humidity'].loc[weather_data['Lat'] >= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(10,20), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("City Latitute vs. Humidity " + cur_date)
plt.savefig("Northern Hemisphere Humidity Regression")
plt.show()

#The below plot is showing a slight trend of increasing humidity, the further away from the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] <= 0]
y_val = weather_data['Humidity'].loc[weather_data['Lat'] <= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] <= 0], weather_data['Humidity'].loc[weather_data['Lat'] <= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(-30,45), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.title("City Latitute vs. Humidity" + cur_date)
plt.savefig("Southern Hemisphere Humidity Regression")
plt.show()

#The below plot is showing a slight trend of increasing humidity, the further away from the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] >= 0]
y_val = weather_data['Cloudiness'].loc[weather_data['Lat'] >= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] >= 0], weather_data['Cloudiness'].loc[weather_data['Lat'] >= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(10,20), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("City Latitute vs. Cloudiness " cur_date)
plt.savefig("Northern Hemisphere Cloudiness Regression")
plt.show()

#The below plot is showing a trend of increasing cloudiness, the further away from the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] <= 0]
y_val = weather_data['Cloudiness'].loc[weather_data['Lat'] <= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] <= 0], weather_data['Cloudiness'].loc[weather_data['Lat'] <= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(-30,60), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.title("City Latitute vs. Cloudiness " + cur_date)
plt.savefig("Southern Hemisphere Cloudiness Regression")
plt.show()

#The below plot is showing a trend of increasing cloudiness, the closer to the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] >= 0]
y_val = weather_data['Wind Speed'].loc[weather_data['Lat'] >= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] >= 0], weather_data['Wind Speed'].loc[weather_data['Lat'] >= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(10,20), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitute vs. Wind Speed " + cur_date)
plt.savefig("Northern Hemisphere Wind Speed Regression")
plt.show()

#The below plot is showing a slight trend of increasing increasing wind speed, the further from the equator the city is.

# %%
x_val = weather_data['Lat'].loc[weather_data['Lat'] <= 0]
y_val = weather_data['Wind Speed'].loc[weather_data['Lat'] <= 0]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

print(f"The r-value is: {rvalue**2}")


plt.scatter(weather_data['Lat'].loc[weather_data['Lat'] <= 0], weather_data['Wind Speed'].loc[weather_data['Lat'] <= 0], color = "blue")
plt.plot(x_val, regress_values, "r-")
plt.annotate(line_eq,(-30,15), fontsize="15", color = "red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title("City Latitute vs. Wind Speed " + cur_date)
plt.savefig("Southern Hemisphere Wind Speed Regression")
plt.show()

#The below plot is showing a slight trend of decreasing wind speed, the closer to the equator the city is.
